# %%
import numpy as np
import matplotlib.pyplot as plt 
from PIL import Image

# %%
img = Image.open('Inputs/cropped_grayscale_check.jpg')
check_GS = np.array(img.convert('L')) 
flat_check_GS = check_GS.flatten()
# plt.imshow(check_GS, cmap='gray')

check_GS_hist, check_GS_bins = np.histogram(flat_check_GS, bins = 256) # if you want a proper histogram
# plt.stairs(check_GS_hist, check_GS_bins)

'''
Now we cut off pixels higher than 125 as a threhold
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [19], in <cell line: 16>()
#      14 mask = check_GS_hist < threshold
#      15 thresholdsegmented_check_GS_hist = check_GS_hist[mask]
# ---> 16 plt.stairs(thresholdsegmented_check_GS_hist, check_GS_bins)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py:2603, in stairs(values, edges, orientation, baseline, fill, data, **kwargs)
#    2599 @_copy_docstring_and_deprecators(Axes.stairs)
#    2600 def stairs(
#    2601         values, edges=None, *, orientation='vertical', baseline=0,
#    2602         fill=False, data=None, **kwargs):
# -> 2603     return gca().stairs(
#    2604         values, edges=edges, orientation=orientation,
#    2605         baseline=baseline, fill=fill,
#    2606         **({"data": data} if data is not None else {}), **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py:6864, in Axes.stairs(self, values, edges, orientation, baseline, fill, **kwargs)
#    6859     edges = np.arange(len(values) + 1)
#    6861 edges, values, baseline = self._process_unit_info(
#    6862     [("x", edges), ("y", values), ("y", baseline)], kwargs)
# -> 6864 patch = mpatches.StepPatch(values,
#    6865                            edges,
#    6866                            baseline=baseline,
#    6867                            orientation=orientation,
#    6868                            fill=fill,
#    6869                            **kwargs)
#    6870 self.add_patch(patch)
#    6871 if baseline is None:
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py:968, in StepPatch.__init__(self, values, edges, orientation, baseline, **kwargs)
#     966 self._values = np.asarray(values)
#     967 self._baseline = np.asarray(baseline) if baseline is not None else None
# --> 968 self._update_path()
#     969 super().__init__(self._path, **kwargs)
#
# File C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\patches.py:975, in StepPatch._update_path(self)
#     973     raise ValueError('Nan values in "edges" are disallowed')
#     974 if self._edges.size - 1 != self._values.size:
# --> 975     raise ValueError('Size mismatch between "values" and "edges". '
#     976                      "Expected `len(values) + 1 == len(edges)`, but "
#     977                      f"`len(values) = {self._values.size}` and "
#     978                      f"`len(edges) = {self._edges.size}`.")
#     979 # Initializing with empty arrays allows supporting empty stairs.
#     980 verts, codes = [np.empty((0, 2))], [np.empty(0, dtype=Path.code_type)]
#
# ValueError: Size mismatch between "values" and "edges". Expected `len(values) + 1 == len(edges)`, but `len(values) = 121` and `len(edges) = 257`.
